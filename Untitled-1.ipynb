# %%
from qiskit import *
from qiskit.visualization import *
from qiskit.quantum_info import *
from ipywidgets import interactive, FloatSlider
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Exploring Qiskit

# %%
c = QuantumCircuit(1,1)

simulator = Aer.get_backend('statevector_simulator')
result = execute(c, simulator).result()
c_state = result.get_statevector()

# %%
def getState(c):
    result = execute(c, simulator).result()
    c_state = result.get_statevector()
    return c_state

# %%
plot_bloch_multivector(c_state)

# %%
plot_state_paulivec(c_state)

# %%
state = Statevector(c_state)

print(state)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
c.h(0)

simulator = Aer.get_backend('statevector_simulator')
result = execute(c, simulator).result()
c_state = result.get_statevector()

plot_bloch_multivector(c_state)

# %%
plot_state_qsphere(c_state)

# %%
c.y(0)

result = execute(c, simulator).result()
c_state = result.get_statevector()

plot_bloch_multivector(c_state)

plot_state_qsphere(c_state)

# %%
plot_bloch_multivector(c_state)

# %%
c.draw('mpl')

# %%
plot_state_paulivec(getState(c))
plot_state_qsphere(getState(c))

# %%
c.h(0)

plot_bloch_multivector(getState(c))

# %%
c.h(0)
plot_state_city(getState(c))

# %%
plot_bloch_multivector(getState(c))

# %%
c.h(0)
plot_bloch_multivector(getState(c))

# %%
c.draw()
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐
#   q: ┤ H ├┤ Y ├┤ H ├┤ H ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘
# c: 1/═════════════════════════

# %%
ket = Statevector(c)
ket.draw(output='latex')
# Out:
# $$- i |1\rangle$$

# %%
ket.draw('hinton')

# %%
from qiskit import Aer
from qiskit.visualization import plot_histogram
def getCounts(ket,n):
 counts = {}
 for i, state in enumerate(ket):
        binary_str = format(i, '0' + str(n) + 'b')
        probability = abs(state) ** 2
        counts[binary_str] = probability


 return counts
 

# Assuming 'ket' is a valid state vector and 'n_qubits' is the number of qubits
#Histogram(ket, 1)

# %%
getCounts(ket,1)
# Out:
#   Cell In[48], line 1
#     def Histogram(ket,n):
#                          ^
# SyntaxError: incomplete input

# %%
counts =getCounts(ket,1)
plot_histogram(counts)
